# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data = pd.read_csv('../archive(3)/twitter_human_bots_dataset.csv')

# %%
data[:5]
# Out:
#    Unnamed: 0           created_at  default_profile  default_profile_image  \
# 0           0  2009-07-04 22:41:51            False                  False
# 1           1  2010-01-17 22:54:19            False                  False
# 2           2  2012-03-01 06:05:32            False                  False
# 3           3  2009-09-01 04:52:30            False                  False
# 4           4  2010-01-27 17:17:23            False                  False
#
#                                          description  favourites_count  \
# 0                                                NaN              5007
# 1  Television producer. Emmy Award winner. Disney...              1038
# 2                                                NaN              2257
# 3                                                NaN              6407
# 4  Productor de Televisión - Embajador de @Tienda...             20866
#
#    followers_count  friends_count  geo_enabled         id  ...  \
# 0              102            168        False   53779179  ...
# 1               60            128        False  105916557  ...
# 2              599            449         True  509788597  ...
# 3              116            334         True   70601327  ...
# 4            74448             18         True  108999927  ...
#
#                                    profile_image_url      screen_name  \
# 0  https://pbs.twimg.com/profile_images/128969130...     paty_castroo
# 1  https://pbs.twimg.com/profile_images/632916759...        CBirckner
# 2  https://pbs.twimg.com/profile_images/128853844...          amf_jay
# 3  https://pbs.twimg.com/profile_images/977012905...       SaraCavolo
# 4  https://pbs.twimg.com/profile_images/668449819...  DavidHenaoModel
#
#   statuses_count verified average_tweets_per_day  account_age_days  \
# 0           3974    False                  0.978              4063
# 1            259    False                  0.067              3866
# 2          13627    False                  4.406              3093
# 3           4432    False                  1.107              4005
# 4          15870     True                  4.116              3856
#
#    account_type                                 profile_image_path  \
# 0           bot                                                NaN
# 1         human  profile_images/4691ae58668d932bb7e7af22141aecf...
# 2         human                                                NaN
# 3         human  profile_images/d1da9220e4aa376dff03b6f12765171...
# 4         human  profile_images/c65bf625b066ef5f29e14cfcf1ee91f...
#
#                        profile_background_image_path split
# 0                                                NaN     0
# 1  profile_images/4691ae58668d932bb7e7af22141aecf...     0
# 2                                                NaN     0
# 3  profile_images/d1da9220e4aa376dff03b6f12765171...     0
# 4  profile_images/c65bf625b066ef5f29e14cfcf1ee91f...     0
#
# [5 rows x 23 columns]

# %%
bot_data = data.loc[data["account_type"] == "bot"]
user_data = data.loc[data["account_type"] == "human"]

# %%
bot_data[:10]
# Out:
#     Unnamed: 0           created_at  default_profile  default_profile_image  \
# 0            0  2009-07-04 22:41:51            False                  False
# 5            5  2017-06-17 05:45:14             True                  False
# 11          11  2015-12-07 21:00:51             True                  False
# 12          12  2009-12-28 03:23:14            False                  False
# 14          14  2012-11-21 23:17:59            False                  False
# 15          15  2012-03-26 19:42:49            False                  False
# 18          18  2017-06-21 02:28:25             True                  False
# 19          19  2013-05-22 14:48:11            False                  False
# 20          20  2009-06-02 03:45:33             True                  False
# 21          21  2009-03-24 02:05:26             True                  False
#
#                                           description  favourites_count  \
# 0                                                 NaN              5007
# 5                                                 NaN                35
# 11                                                NaN               978
# 12         claw behind the paw|Boedoet'12|@GeoUnpad12              2703
# 14                                                NaN              2232
# 15                                                NaN              2098
# 18  ابي انييك ،من يبي زب كبير ورمانسي ونياك وفحل ي...                29
# 19  Here to give you the latest Selena Gomez News....                40
# 20                                                NaN              1164
# 21                                                NaN              1571
#
#     followers_count  friends_count  geo_enabled                  id  ...  \
# 0               102            168        False            53779179  ...
# 5                 0              0        False  875952456060084225  ...
# 11                3              2        False          4408686088  ...
# 12              498            522        False            99847971  ...
# 14               23              0        False           963263894  ...
# 15               17              4        False           537500546  ...
# 18                1              0        False  877352477280043008  ...
# 19             8662              0        False          1449155815  ...
# 20              593           4813        False            44051445  ...
# 21               11             81        False            26152058  ...
#
#                                     profile_image_url      screen_name  \
# 0   https://pbs.twimg.com/profile_images/128969130...     paty_castroo
# 5   https://pbs.twimg.com/profile_images/875955014...  ndtjgaogywxeei1
# 11  https://pbs.twimg.com/profile_images/673971044...  vicentecruz2016
# 12  https://pbs.twimg.com/profile_images/425968819...      pichapriska
# 14  https://pbs.twimg.com/profile_images/290810213...        baregoods
# 15  https://pbs.twimg.com/profile_images/196418671...  NalmaryCasablan
# 18  https://pbs.twimg.com/profile_images/879618666...   zvsnfaqrgk1359
# 19  https://pbs.twimg.com/profile_images/106979072...      SelenaGCrew
# 20  https://pbs.twimg.com/profile_images/449276692...    veganicecream
# 21  https://pbs.twimg.com/profile_images/108032837...             sp3n
#
#    statuses_count verified average_tweets_per_day  account_age_days  \
# 0            3974    False                  0.978              4063
# 5             227    False                  0.196              1159
# 11           1405    False                  0.819              1716
# 12           5614    False                  1.444              3887
# 14           3151    False                  1.115              2827
# 15           2911    False                  0.949              3067
# 18            172    False                  0.149              1155
# 19          26778    False                 10.124              2645
# 20          12744    False                  3.111              4096
# 21           2205    False                  0.529              4166
#
#     account_type                                 profile_image_path  \
# 0            bot                                                NaN
# 5            bot  profile_images/848c190606cd415153938b4e45ec83f...
# 11           bot  profile_images/1e7e50de5cd1347256dcf3aca0cb6ab...
# 12           bot  profile_images/08032cb0b162f9782f78914ea8b4450...
# 14           bot  profile_images/00b719ff02ff287f0fa22684739644e...
# 15           bot  profile_images/d285cf6706c589a2d2abc893b668c01...
# 18           bot  profile_images/4ea05ed522e91fb7cb3eb3a0317e30f...
# 19           bot  profile_images/4e5b235c6f3af80a59a5623d35b67c0...
# 20           bot  profile_images/de9c49cbb734cb77331ea84db3f51a9...
# 21           bot  profile_images/76de61d6983b02db788502b999181a1...
#
#                         profile_background_image_path split
# 0                                                 NaN     0
# 5   profile_images/848c190606cd415153938b4e45ec83f...     0
# 11  profile_images/1e7e50de5cd1347256dcf3aca0cb6ab...     0
# 12  profile_images/08032cb0b162f9782f78914ea8b4450...     0
# 14  profile_images/00b719ff02ff287f0fa22684739644e...     0
# 15  profile_images/d285cf6706c589a2d2abc893b668c01...     0
# 18  profile_images/4ea05ed522e91fb7cb3eb3a0317e30f...     0
# 19  profile_images/4e5b235c6f3af80a59a5623d35b67c0...     0
# 20  profile_images/de9c49cbb734cb77331ea84db3f51a9...     0
# 21  profile_images/76de61d6983b02db788502b999181a1...     0
#
# [10 rows x 23 columns]

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

data['bot'] = data['account_type'].apply(lambda x: 1 if x == 'bot' else 0)
data['default_profile'] = data['default_profile'].astype(int)
data['default_profile'] = data['default_profile'].astype(int)
data['default_profile_image'] = data['default_profile_image'].astype(int)
data['geo_enabled'] = data['geo_enabled'].astype(int)
data['verified'] = data['verified'].astype(int)

# datetime conversion
data['created_at'] = pd.to_datetime(data['created_at'])
# hour created
data['hour_created'] = pd.to_datetime(data['created_at']).dt.hour

# %%
df = data[['bot', 'screen_name', 'created_at', 'hour_created', 'verified', 'geo_enabled', 'lang', 'default_profile', 
              'default_profile_image', 'favourites_count', 'followers_count', 'friends_count', 'statuses_count',
             'average_tweets_per_day', 'account_age_days']]

del data

# %%
df.head()
# Out:
#    bot      screen_name          created_at  hour_created  verified  \
# 0    1     paty_castroo 2009-07-04 22:41:51            22         0
# 1    0        CBirckner 2010-01-17 22:54:19            22         0
# 2    0          amf_jay 2012-03-01 06:05:32             6         0
# 3    0       SaraCavolo 2009-09-01 04:52:30             4         0
# 4    0  DavidHenaoModel 2010-01-27 17:17:23            17         1
#
#    geo_enabled lang  default_profile  default_profile_image  favourites_count  \
# 0            0  NaN                0                      0              5007
# 1            0   en                0                      0              1038
# 2            1  NaN                0                      0              2257
# 3            1  NaN                0                      0              6407
# 4            1   es                0                      0             20866
#
#    followers_count  friends_count  statuses_count  average_tweets_per_day  \
# 0              102            168            3974                   0.978
# 1               60            128             259                   0.067
# 2              599            449           13627                   4.406
# 3              116            334            4432                   1.107
# 4            74448             18           15870                   4.116
#
#    account_age_days
# 0              4063
# 1              3866
# 2              3093
# 3              4005
# 4              3856

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37438 entries, 0 to 37437
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   bot                     37438 non-null  int64
#  1   screen_name             37438 non-null  object
#  2   created_at              37438 non-null  datetime64[ns]
#  3   hour_created            37438 non-null  int32
#  4   verified                37438 non-null  int64
#  5   geo_enabled             37438 non-null  int64
#  6   lang                    29481 non-null  object
#  7   default_profile         37438 non-null  int64
#  8   default_profile_image   37438 non-null  int64
#  9   favourites_count        37438 non-null  int64
#  10  followers_count         37438 non-null  int64
#  11  friends_count           37438 non-null  int64
#  12  statuses_count          37438 non-null  int64
#  13  average_tweets_per_day  37438 non-null  float64
#  14  account_age_days        37438 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(10), object(2)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#                 bot                     created_at  hour_created  \
# count  37438.000000                          37438  37438.000000
# mean       0.331882  2012-05-10 19:06:11.558710016     12.371040
# min        0.000000            2006-07-05 19:52:46      0.000000
# 25%        0.000000  2009-12-26 20:54:38.750000128      5.000000
# 50%        0.000000            2011-10-27 02:04:41     14.000000
# 75%        1.000000            2014-04-16 15:39:40     19.000000
# max        1.000000            2019-04-24 08:53:21     23.000000
# std        0.470895                            NaN      7.325433
#
#            verified   geo_enabled  default_profile  default_profile_image  \
# count  37438.000000  37438.000000     37438.000000           37438.000000
# mean       0.201693      0.456141         0.419894               0.014905
# min        0.000000      0.000000         0.000000               0.000000
# 25%        0.000000      0.000000         0.000000               0.000000
# 50%        0.000000      0.000000         0.000000               0.000000
# 75%        0.000000      1.000000         1.000000               0.000000
# max        1.000000      1.000000         1.000000               1.000000
# std        0.401270      0.498079         0.493548               0.121173
#
#        favourites_count  followers_count  friends_count  statuses_count  \
# count      37438.000000     3.743800e+04   3.743800e+04    3.743800e+04
# mean       12302.062183     3.703098e+05   4.445925e+03    2.107339e+04
# min            0.000000     0.000000e+00   0.000000e+00    0.000000e+00
# 25%          362.000000     3.500000e+01   3.700000e+01    1.336250e+03
# 50%         2066.000000     3.650000e+02   2.960000e+02    4.209000e+03
# 75%         8879.000000     8.440250e+03   8.930000e+02    1.715375e+04
# max       885123.000000     1.216415e+08   4.343060e+06    2.771910e+06
# std        33923.650237     2.470829e+06   4.954520e+04    6.732977e+04
#
#        average_tweets_per_day  account_age_days
# count            37438.000000      37438.000000
# mean                 6.891668       3022.128052
# min                  0.000000        483.000000
# 25%                  0.495000       2316.250000
# 50%                  1.488000       3219.000000
# 75%                  5.528000       3888.000000
# max               1269.055000       5158.000000
# std                 24.580116       1013.695870

# %%
df['avg_daily_followers'] = np.round(df['followers_count'] / df['account_age_days'])
df['avg_daily_friends'] = np.round(df['followers_count'] / df['account_age_days'])
df['avg_daily_favorites'] = np.round(df['followers_count'] / df['account_age_days'])

df['friends_log'] = np.round(np.log(1 + df['friends_count']), 3)
df['followers_log'] = np.round(np.log(1 + df['followers_count']), 3)
df['favs_log'] = np.round(np.log(1 + df['favourites_count']), 3)
df['avg_daily_tweets_log'] = np.round(np.log(1+ df['average_tweets_per_day']), 3)

df['network'] = np.round(df['friends_log'] * df['followers_log'], 3)
df['tweet_to_followers'] = np.round(np.log( 1+ df['statuses_count']) * np.log(1+ df['followers_count']), 3)

df['follower_acq_rate'] = np.round(np.log(1 + (df['followers_count'] / df['account_age_days'])), 3)
df['friends_acq_rate'] = np.round(np.log(1 + (df['friends_count'] / df['account_age_days'])), 3)
df['favs_rate'] = np.round(np.log(1 + (df['friends_count'] / df['account_age_days'])), 3)

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='account_age_days', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title('Distribution of Account Ages', fontsize=12)
plt.xlabel('Account Age (# days)', fontsize=10)
plt.ylabel('Density', fontsize=10)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='followers_log', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title('Distribution of # Followers', fontsize=12)
plt.xlabel('Followers (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 18)
plt.ylim(0, 0.11)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='friends_log', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title('Distribution of Friends (# Following)', fontsize=12)
plt.xlabel('Friends Count (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 16)
plt.ylim(0, 0.65)
sns.despine()

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.suptitle('Distribution of Followers & Friends', fontsize=14)

plt.subplot(1, 2, 1)
sns.histplot(x='followers_log', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])
plt.title('Distribution of # Followers', fontsize=12)
plt.xlabel('Followers (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 18)
plt.ylim(0, 0.25)
sns.despine()

plt.subplot(1, 2, 2)
sns.histplot(x='friends_log', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])
plt.title('Distribution of Friends (# Following)', fontsize=12)
plt.xlabel('Friends Count (Log10 scale)', fontsize=10)
plt.ylabel("")
plt.yticks([])
plt.xlim(0, 18)
plt.ylim(0, 0.25)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='network', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title('Distribution of Network Size', fontsize=12)
plt.xlabel('Network Size [Friends * Followers] (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 150)
plt.ylim(0, 0.05)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='favs_log', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title("Distribution of Favorites Count", fontsize=12)
plt.xlabel('Favorites Count(Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 14)
plt.ylim(0, 0.3)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='avg_daily_tweets_log', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title("Distribution of Tweets per Day", fontsize=12)
plt.xlabel('Average Tweets per Day (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 5)
plt.ylim(0, 0.7)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='tweet_to_followers', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title("Tweets to Followers Metric", fontsize=12)
plt.xlabel('Tweets * Followers (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 200)
plt.ylim(0, 0.009)
sns.despine()

# %%
plt.figure(figsize=(7,5), dpi=100)
sns.histplot(x='hour_created', data=df, hue='bot', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])

plt.title("Time of Day Account was Created", fontsize=12)
plt.xlabel('Time of Day (24h)', fontsize=10)
plt.ylabel('Density', fontsize=10)
plt.xlim(0, 24)
plt.ylim(0, 0.05)
sns.despine()

# %%
bots = df[df['bot'] == 1]
humans = df[df['bot'] == 0]

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.suptitle('Network Size by Verification Status', fontsize=14)

plt.subplot(1, 2, 1)
sns.histplot(x='network', data=humans, hue='verified', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])
plt.xlabel('Network Size (Friends * Followers)')
plt.title("Humans", fontsize=12)
plt.xlabel('Network Size (Log10 scale)', fontsize=10)
plt.ylabel('Density', fontsize=10)
sns.despine(bottom = True, left = True)
plt.xlim(0, 150)
plt.ylim(0, 0.05)

plt.subplot(1, 2, 2)
sns.histplot(x='network', data=bots, hue='verified', alpha=.25, 
             kde=True, stat='density', common_bins=True, element='step', legend=True, palette=['blue', 'red'])
plt.xlabel('Network Size (Friends * Followers)')
# plt.legend(title='Verification Status', loc='upper right', labels=['Verified', 'Not Verified'], frameon=False)
plt.title("Bots", fontsize=12)
plt.xlabel('Network Size (Log10 scale)', fontsize=10)
plt.ylabel("")
plt.yticks([])
sns.despine()
plt.xlim(0, 150)
plt.ylim(0, 0.05)
# Out:
# (0.0, 0.05)

# %%
df.to_csv('cleaned_data.csv', index=False)
